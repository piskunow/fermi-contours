# %% [markdown]
# # Tutorial

# %% [markdown]
# ## Computing contours of a custom function
# The function defines a 3d surface, for which we will compute its contours.

# %% [markdown]
# We start by importing our library and some plotting functions.

# %%
import numpy as np

from fermi_contours import marching_squares as ms

from matplotlib import pyplot as plt
from matplotlib import colors
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %% [markdown]
# The custom function can be anything that takes two floats and returns another float.
# If the function is expensive to compute in a serial way, consider computing the `grid_values` elsewhere, and provide the values instead of the function.

# %%
def surface(x, y):
    return x ** 2 + y ** 2

# %% [markdown]
# To instantiate our `MarchingSquares` class, we need to provide the bounds of the grid. These bounds will be used to scale the position of the contours.

# %%
squares = ms.MarchingSquares(
    func=surface,
    res=[20, 10],
    bounds=[[-2,2], [-1, 1]],
)

# %% [markdown]
# At this point, the `squares` instance has extracted the `grid_points` and their `grid_values`.
# If these are not provided, the `grid_points` are computed them using the `res` and `bounds` parameters, and the `grid_values` are the evaluations of `func` on those points.

# %%
X, Y = np.meshgrid(*squares.grid_points)
plt.pcolormesh(X, Y, squares.grid_values.T, cmap="Blues");

# %% [markdown]
# ### Computing contours
# Now, we just call our instance with the values of the levels for which we want to compute the contour.

# %%
levels = np.linspace(0, 1, 21)
levels
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])

# %%
contours = [squares(l) for l in levels]
# Out:
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (8, 3).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (8, 4).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (7, 3).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (8, 2).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (10, 5).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (7, 4).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (7, 2).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (6, 3).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (11, 5).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (6, 4).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (8, 1).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (10, 6).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (6, 2).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (7, 1).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (11, 6).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (5, 3).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (6, 1).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (12, 5).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (5, 4).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (8, 0).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (10, 7).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (5, 2).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (12, 6).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (7, 0).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (11, 7).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (5, 1).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (6, 0).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (12, 7).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (4, 3).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (13, 5).
#   warn(f"Stepping outside the initial path with cell {ij}.")
# /home/pablo/work/fermi-contours/src/fermi_contours/marching_squares.py:268: UserWarning: Stepping outside the initial path with cell (4, 4).
#   warn(f"Stepping outside the initial path with cell {ij}.")

# %% [markdown]
# To visualize the contours, we can plot the `grid_values` in blue, and the set of contours in orange.

# %%
fig, ax = plt.subplots()


n = len(levels)
color_list = plt.cm.Oranges(np.linspace(0, 1, n))

cmap = plt.cm.Oranges
norm = colors.Normalize(vmin=levels[0], vmax=levels[-1])

for i, contour in enumerate(contours):
    ax.plot(*np.array(contour).T, color=color_list[i])


divider = make_axes_locatable(ax)
cax = divider.new_horizontal(size="5%", pad=0.2)
fig.add_axes(cax)
fig.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap), cax=cax)
X, Y = np.meshgrid(*squares.grid_points)
ax.pcolormesh(X, Y, squares.grid_values.T, cmap="Blues");

# %%
fig, ax = plt.subplots(subplot_kw=dict(projection='3d', computed_zorder=False))

X, Y = np.meshgrid(*squares.grid_points)
ax.plot_surface(X, Y, squares.grid_values.T, alpha=1, cmap="Blues")
ax.view_init(azim=-80, elev=20)

n = len(levels)
color_list = plt.cm.Oranges(np.linspace(0, 1, n))

cmap = plt.cm.Oranges
norm = colors.Normalize(vmin=levels[0], vmax=levels[-1])

for i, (level, contour) in enumerate(zip(levels, contours)):
    if len(contour) > 0:
        _x, _y = np.array(contour).T
        _z = np.ones(len(_x))[:, None] * level
        ax.plot(_x, _y, _z, color=color_list[i])

# %% [markdown]
# ## Special cases
#
# ### Open contours
#
# It may happen that our contour is not closed, or at least not within the bounds that we want.
# In this case, we can set the parameter `open_contours=True` to allow this behaviour.
# This can also lead to more than one contour per level
#
#
# ### Periodic boundaries
# If we want that contours wrap around the edges of our grid, we can set the parameter `periodic=True`.
